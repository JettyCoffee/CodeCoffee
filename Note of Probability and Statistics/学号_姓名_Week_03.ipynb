# %% [markdown]
# ## 第三至四周作业
#
# #### 提交人学号：XXXX
# #### 提交人姓名：张三
#
# #### 作业题目：
# 考虑以下分布，并比较异同。
#
# 第一组
#
# （1）二项分布$b(5,0.4)$;
#
# （2）二项分布$b(10,0.4)$;
#
# （3）泊松分布$p(4)$;
#
# 第二组
#
# （4）正态分布$N(0,1)$;
#
# （5）正态分布$N(1,1)$;
#
# （6）正态分布$N(1,3)$;
#
# 第三组
#
# （7）指数分布$Exp(1)$;
#
# （8）伽马分布$Ga(1,1/2)$;
#
# （9）伽马分布$Ga(1/2,1/2)$;
#
# 完成以下问题：
# - 分别写出所有分布的概率分布列或概率密度函数，并绘制图象；
# - 分别绘制所有分布的分布函数图象；
# - 请简要阐述所列出每个组内各分布之间的联系、相似与相异；
#
#
# #### 可参考的python代码【在所提交的作业中，所有【】标记的内容可删除】

# %%
import matplotlib.pyplot as plt
import numpy as np
 
# 生成一个在[0, 1)范围内的随机小数
x = np.linspace(0, 10, 100)
y1 = 4 + 3 * np.sin(2*x)
y2 = 4 + 3 * np.cos(2*x)

plt.style.use("tableau-colorblind10") 
# 26 style
#'Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 
#'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 
#'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid',
#'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel',
#'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 
#'tableau-colorblind10'
fig, ax = plt.subplots()
# 绘制蓝色实线
ax.plot(x,y1) 
# 绘制红色虚线
ax.plot(x,y2,'r--') # r: red; --: dash line
plt.show()

# %% [markdown]
# #### 解答：【结合python运算结果，写解答过程】

# %% [markdown]
# 参考资料：
# Python matplotlib 使用教程：https://matplotlib.org/stable/index.html
